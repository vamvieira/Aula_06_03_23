# %%
# %matplotlib inline 
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread("Naruto.png")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

image_lower_hav = np.array([0,80,30])
image_upper_hav = np.array([200,255,255])

mask_hav = cv2.inRange(img_hsv, image_lower_hav, image_upper_hav)

plt.subplot()
plt.imshow(img_rgb)
plt.show() 
plt.subplot()
plt.imshow(mask_hav, cmap="Greys_r", vmin=0,vmax=255)
plt.show()

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread('bolinha.png')

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# o magenta tem h=300 mais ou menos ou 150 para a OpenCV
image_lower_hsv = np.array([140, 50, 100])  
image_upper_hsv = np.array([170, 255, 255])


mask_hsv = cv2.inRange(img_hsv, image_lower_hsv, image_upper_hsv)

plt.subplot()
plt.imshow(img_rgb)
plt.show()
plt.subplot()
plt.imshow(mask_hsv, cmap="Greys_r", vmin=0, vmax=255)
plt.show()

# %%
contornos, _ = cv2.findContours(mask_hsv, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# para desenhar o contorno primeiro faz uma copia da imagem 

mask_rgb = cv2.cvtColor(mask_hsv, cv2.COLOR_GRAY2RGB) 
contornos_img = mask_rgb.copy() # Cópia da máscara para ser desenhada "por cima"

cv2.drawContours(contornos_img, contornos, -1, [255, 0, 0], 5);

plt.figure(figsize=(8,6))
plt.imshow(contornos_img);

# %%
# para desenhar o contorno primeiro faz uma copia da imagem 

mask_rgb = cv2.cvtColor(mask_hsv, cv2.COLOR_GRAY2RGB) 
contornos_img = mask_rgb.copy() # Cópia da máscara para ser desenhada "por cima"

cv2.drawContours(img_rgb, contornos, -1, [0, 0, 255], 10);

plt.figure(figsize=(8,6))
plt.imshow(img_rgb);

# %%
# %matplotlib inline 
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread("formas.png")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

image_lower_hav = np.array([0,10,50])
image_upper_hav = np.array([255,255,255])

mask_hav = cv2.inRange(img_hsv, image_lower_hav, image_upper_hav)

plt.subplot()
plt.imshow(img_rgb)
plt.show() 
plt.subplot()
plt.imshow(mask_hav, cmap="Greys_r", vmin=0,vmax=255)
plt.show()
